# %% [markdown]
# ## EXERCISE DAY 23

# %%
# !pip install virtualenv
# Out:
# ...
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.8 MB 163.8 kB/s eta 0:00:23
#    ---------------------------------------- 0.0/3.8 MB 163.8 kB/s eta 0:00:23
#    ---------------------------------------- 0.0/3.8 MB 163.8 kB/s eta 0:00:23
#     --------------------------------------- 0.1/3.8 MB 164.1 kB/s eta 0:00:23
#     --------------------------------------- 0.1/3.8 MB 164.1 kB/s eta 0:00:23
#     --------------------------------------- 0.1/3.8 MB 164.1 kB/s eta 0:00:23
#     --------------------------------------- 0.1/3.8 MB 164.1 kB/s eta 0:00:23
#     --------------------------------------- 0.1/3.8 MB 112.3 kB/s eta 0:00:34
#     --------------------------------------- 0.1/3.8 MB 112.3 kB/s eta 0:00:34
#     --------------------------------------- 0.1/3.8 MB 112.3 kB/s eta 0:00:34
# ...

# %%
import virtualenv

# %% [markdown]
# I have practiced the assignment on virtual environment
